# %% [markdown]
# # 🥙 LSTM on Recipe Data

# %% [markdown]
# In this notebook, we'll walk through the steps required to train your own LSTM on the recipes dataset

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import json
import re
import string

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, losses

# %% [markdown]
# ## 0. Parameters <a name="parameters"></a>

# %%
VOCAB_SIZE = 10000
MAX_LEN = 200
EMBEDDING_DIM = 100
N_UNITS = 128
VALIDATION_SPLIT = 0.2
SEED = 42
LOAD_MODEL = False
BATCH_SIZE = 32
EPOCHS = 25

# %% [markdown]
# ## 1. Load the data <a name="load"></a>

# %%
# Load the full dataset
with open("full_format_recipes.json") as json_data:
    recipe_data = json.load(json_data)

# %%
# Filter the dataset
filtered_data = [
    "Recipe for " + x["title"] + " | " + " ".join(x["directions"])
    for x in recipe_data
    if "title" in x
    and x["title"] is not None
    and "directions" in x
    and x["directions"] is not None
]

# %%
# Count the recipes
n_recipes = len(filtered_data)
print(f"{n_recipes} recipes loaded")
# Out:
# 20111 recipes loaded

# %%
example = filtered_data[9]
print(example)
# Out:
# Recipe for Ham Persillade with Mustard Potato Salad and Mashed Peas  | Chop enough parsley leaves to measure 1 tablespoon; reserve. Chop remaining leaves and stems and simmer with broth and garlic in a small saucepan, covered, 5 minutes. Meanwhile, sprinkle gelatin over water in a medium bowl and let soften 1 minute. Strain broth through a fine-mesh sieve into bowl with gelatin and stir to dissolve. Season with salt and pepper. Set bowl in an ice bath and cool to room temperature, stirring. Toss ham with reserved parsley and divide among jars. Pour gelatin on top and chill until set, at least 1 hour. Whisk together mayonnaise, mustard, vinegar, 1/4 teaspoon salt, and 1/4 teaspoon pepper in a large bowl. Stir in celery, cornichons, and potatoes. Pulse peas with marjoram, oil, 1/2 teaspoon pepper, and 1/4 teaspoon salt in a food processor to a coarse mash. Layer peas, then potato salad, over ham.

# %% [markdown]
# ## 2. Tokenise the data

# %%
# Pad the punctuation, to treat them as separate 'words'
def pad_punctuation(s):
    s = re.sub(f"([{string.punctuation}])", r" \1 ", s)
    s = re.sub(" +", " ", s)
    return s


text_data = [pad_punctuation(x) for x in filtered_data]

# %%
# Display an example of a recipe
example_data = text_data[9]
example_data
# Out:
# 'Recipe for Ham Persillade with Mustard Potato Salad and Mashed Peas | Chop enough parsley leaves to measure 1 tablespoon ; reserve . Chop remaining leaves and stems and simmer with broth and garlic in a small saucepan , covered , 5 minutes . Meanwhile , sprinkle gelatin over water in a medium bowl and let soften 1 minute . Strain broth through a fine - mesh sieve into bowl with gelatin and stir to dissolve . Season with salt and pepper . Set bowl in an ice bath and cool to room temperature , stirring . Toss ham with reserved parsley and divide among jars . Pour gelatin on top and chill until set , at least 1 hour . Whisk together mayonnaise , mustard , vinegar , 1 / 4 teaspoon salt , and 1 / 4 teaspoon pepper in a large bowl . Stir in celery , cornichons , and potatoes . Pulse peas with marjoram , oil , 1 / 2 teaspoon pepper , and 1 / 4 teaspoon salt in a food processor to a coarse mash . Layer peas , then potato salad , over ham . '

# %%
# Convert to a Tensorflow Dataset
text_ds = (
    tf.data.Dataset.from_tensor_slices(text_data)
    .batch(BATCH_SIZE)
    .shuffle(1000)
)

# %%
# Create a vectorisation layer
vectorize_layer = layers.TextVectorization(
    standardize="lower",
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=MAX_LEN + 1,
)

# %%
# Adapt the layer to the training set
vectorize_layer.adapt(text_ds)
vocab = vectorize_layer.get_vocabulary()
# Out:
# 2025-02-16 13:39:18.589804: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Display some token:word mappings
for i, word in enumerate(vocab[:10]):
    print(f"{i}: {word}")
# Out:
# 0:
# 1: [UNK]
# 2: .
# 3: ,
# 4: and
# 5: to
# 6: in
# 7: the
# 8: with
# 9: a

# %%
# Display the same example converted to ints
example_tokenised = vectorize_layer(example_data)
print(example_tokenised.numpy())
# Out:
# [  26   16  557    1    8  298  335  189    4 1054  494   27  332  228
#   235  262    5  594   11  133   22  311    2  332   45  262    4  671
#     4   70    8  171    4   81    6    9   65   80    3  121    3   59
#    12    2  299    3   88  650   20   39    6    9   29   21    4   67
#   529   11  164    2  320  171  102    9  374   13  643  306   25   21
#     8  650    4   42    5  931    2   63    8   24    4   33    2  114
#    21    6  178  181 1245    4   60    5  140  112    3   48    2  117
#   557    8  285  235    4  200  292  980    2  107  650   28   72    4
#   108   10  114    3   57  204   11  172    2   73  110  482    3  298
#     3  190    3   11   23   32  142   24    3    4   11   23   32  142
#    33    6    9   30   21    2   42    6  353    3 3224    3    4  150
#     2  437  494    8 1281    3   37    3   11   23   15  142   33    3
#     4   11   23   32  142   24    6    9  291  188    5    9  412  572
#     2  230  494    3   46  335  189    3   20  557    2    0    0    0
#     0    0    0    0    0]

# %% [markdown]
# ## 3. Create the Training Set

# %%
# Create the training set of recipes and the same text shifted by one word
def prepare_inputs(text):
    text = tf.expand_dims(text, -1)
    tokenized_sentences = vectorize_layer(text)
    x = tokenized_sentences[:, :-1]
    y = tokenized_sentences[:, 1:]
    return x, y


train_ds = text_ds.map(prepare_inputs)

# %% [markdown]
# ## 4. Build the LSTM <a name="build"></a>

# %%
inputs = layers.Input(shape=(None,), dtype="int32")
x = layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)(inputs)
x = layers.LSTM(N_UNITS, return_sequences=True)(x)
outputs = layers.Dense(VOCAB_SIZE, activation="softmax")(x)
lstm = models.Model(inputs, outputs)
lstm.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, None)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Embedding)           │ (None, None, 100)      │     1,000,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, None, 128)      │       117,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, None, 10000)    │     1,290,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,407,248 (9.18 MB)
#  Trainable params: 2,407,248 (9.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
if LOAD_MODEL:
    # model.load_weights('./models/model')
    lstm = models.load_model("./models/lstm", compile=False)

# %% [markdown]
# ## 5. Train the LSTM <a name="train"></a>

# %%
loss_fn = losses.SparseCategoricalCrossentropy()
lstm.compile("adam", loss_fn)

# %%
# Create a TextGenerator checkpoint
class TextGenerator(callbacks.Callback):
    def __init__(self, index_to_word, top_k=10):
        self.index_to_word = index_to_word
        self.word_to_index = {
            word: index for index, word in enumerate(index_to_word)
        }  # <1>

    def sample_from(self, probs, temperature):  # <2>
        probs = probs ** (1 / temperature)
        probs = probs / np.sum(probs)
        return np.random.choice(len(probs), p=probs), probs

    def generate(self, start_prompt, max_tokens, temperature):
        start_tokens = [
            self.word_to_index.get(x, 1) for x in start_prompt.split()
        ]  # <3>
        sample_token = None
        info = []
        while len(start_tokens) < max_tokens and sample_token != 0:  # <4>
            x = np.array([start_tokens])
            y = self.model.predict(x, verbose=0)  # <5>
            sample_token, probs = self.sample_from(y[0][-1], temperature)  # <6>
            info.append({"prompt": start_prompt, "word_probs": probs})
            start_tokens.append(sample_token)  # <7>
            start_prompt = start_prompt + " " + self.index_to_word[sample_token]
        print(f"\ngenerated text:\n{start_prompt}\n")
        return info

    def on_epoch_end(self, epoch, logs=None):
        self.generate("recipe for", max_tokens=100, temperature=1.0)

# %%
# Create a model save checkpoint
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="./checkpoint/checkpoint.weights.h5",
    save_weights_only=True,
    save_freq="epoch",
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")

# Tokenize starting prompt
text_generator = TextGenerator(vocab)

# %%
lstm.fit(
    train_ds,
    epochs=EPOCHS,
    callbacks=[model_checkpoint_callback, tensorboard_callback, text_generator],
)
# Out:
# Epoch 1/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - loss: 4.2907
# generated text:
# recipe for thyme with gently tomato greens | drop juice first rack and a boil in large water , / taste ; cook and low with just until time
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 266s 422ms/step - loss: 4.2901
# Epoch 2/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 2.9667
# generated text:
# recipe for cookies goblets with mushroom squash , and roast , and rice | combine first 1 tablespoon butter in a large a medium manner . add by 3 teaspoons sauce in blender . stir in ground the fried pepper and until slightly grill , about 5 minutes . place preheat dish ; stir in the water bulb . using mixer the pot halfway through 12 cast over a ball , just wedge , at quart lower stream , ( . transfer
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 271s 430ms/step - loss: 2.9665
# Epoch 3/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 2.4786
# generated text:
# recipe for snow potato and herb fruit | finely fresh cranberry cheese on rimmed baking sheet slice . steam bread in bowl and let sit 10 minutes . transfer to low and bring to boil . meanwhile , refrigerate for 5 hours . meanwhile , and cut out 2 inches into a colander . strain vegetables into a small bowl until cold sweet . soak until vegetables are cake just to very very tender , about 20 minutes . wipe gratin grinder . combine 1 / 2 cups sugar , mint ingredients with olive oil enough oven . let ground
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 2217s 4s/step - loss: 2.4785
# Epoch 4/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 2.2337
# generated text:
# recipe for pork steak pie with butter 1 lb cake crust | preheat oven to 350°f . butter 13x9x2 - inch - lined cookie pan , combine , knocking out or pan to deep 1 - quart saucepan , cover , preheat broth . brush a pan sieve with 2 hole . heat 1 bread accumulated in a butter of a pinch of gin , baking powder and sugar and sprinkle with hang . cake shrimp and skillet power clafouti in reserved oil and forth . spoon 2 tablespoons rice over fish crust . mix 3 frosting of nuts breast
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 1937s 3s/step - loss: 2.2336
# Epoch 5/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 2.0878
# generated text:
# recipe for chicken thighs | combine butter ( small turns on the shell ) , and pat them with the fat . ( will be coated to the liner ) . in a bowl or having bury together the top , 1 / 3 cup pea liqueur , and pestle . add the garlic and the vinegar , the mole , and garlic . bring the rice to a boil , and blend . let sit until it is smooth , then drain . transfer the dressing to a bowl , then discard the nuts in the coconut . taste
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 2658s 4s/step - loss: 2.0878
# Epoch 6/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.9729
# generated text:
# recipe for holiday cream hazelnut basil | bring cream just to low , cover and simmer , stirring by 1 / 2 cups , until syrup are raw sugar has dissolved . transfer to bowl , add lemon juice , potatoes , and 1 1 / 2 cups water to same saucepan . bring to boil over moderate heat and blender roux , until very very soft but not drain , and cool 1 tbsp . transfer to a bowl . put oven and 3 tbsp , and cook , stirring occasionally , until standing are golden , about 5
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 865s 1s/step - loss: 1.9729
# Epoch 7/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1.9018
# generated text:
# recipe for lemon juice with omitted with mushrooms and walnuts | bring all flour and 1 tablespoon juice in a heavy - bottomed heavy saucepan over low heat , stirring , until meat thickens , about 20 minutes . add squash and syrup to cover and cook over moderately low heat , stirring constantly with a wooden spoon . add all of caramel , covering a lightly floured surface to fit into a 9 - inch - wide rounds or roll on surface . slit miso and with wet does not sprinkle gelatin over and with dressing running or transfer
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 1250s 2s/step - loss: 1.9018
# Epoch 8/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 874ms/step - loss: 1.8436
# generated text:
# recipe for orzo soup with green onions and spinach | lightly grind remaining ingredients in coarse spice , transfer to large bowl . mix in parsley . let stand at room temperature 1 hour and up 1 day . preheat broiler . sift next 9 - cup of blanched small - large skillet with 3 / 4 cup . heat oil and savory 1 1 / 2 teaspoons water over moderately high heat until pale golden brown , about 5 minutes . transfer to small plate . add liquid , 3 tablespoons oil , and pine nuts ; toss to
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 552s 878ms/step - loss: 1.8436
# Epoch 9/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - loss: 1.8031
# generated text:
# recipe for salt - porterhouse beef & | place 1 tablespoon additional flour on work sheet of water . with orange press mixture , stem spices and mint curls . place tortilla wedges in even layer and place seam and peel halves in dish . gently make at dab , remove any excess center from membranes , then lift bones and hold jam in on lemon . place chicken around center . bake for 45 minutes . if necessary , cool slightly on rack . bake squash , covered , until heated through , about 1 hour 10 minutes .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 323s 513ms/step - loss: 1.8031
# Epoch 10/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 614ms/step - loss: 1.7664
# generated text:
# recipe for spring tangerine gratin with mushrooms and celery | heat oven to 500°f in oven and preheat oven to 350°f . in a blender purée with squid , onion , oregano , garlic , and salt and pepper to taste on a tight - low ( do not allow chorizo to soft it , and make 6 to 4 - inch ) beaten red onion shanks to taste with salt and pepper , then stir together , melted butter , and 1 heavy 1 / 2 tablespoon butter . heat 1 tbsp . oil on a baking sheet to
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 390s 620ms/step - loss: 1.7664
# Epoch 11/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 619ms/step - loss: 1.7369
# generated text:
# recipe for holiday pound ' s cake | biscuit onion and 1 ( fresh ginger ) and discard seeds . in a nonstick skillet cook over moderate heat until hot but not smoking ( carrots will appear 5 seconds ) . melt 3 tablespoons butter in a 5 - inch skillet over moderately high heat until just beginning to touch , about 5 minutes . add gelatin mixture ; set large skillet over simmering water and bring to a boil . using tongs , transfer meringue to a 8 - quart bowl . scoop out cantaloupe , reserving remaining 2
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 393s 623ms/step - loss: 1.7369
# Epoch 12/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - loss: 1.7009
# generated text:
# recipe for pastry dough | in a small bowl whisk together flour , granulated sugar , whole yeast , and salt and let cool . preheat oven to 350°f . rub butter all over both sides of cornmeal in small large bowl . add 2 teaspoons hot water into baking pan and combine almonds with malted electric mixer until fluffy . add eggs and beat until pale and fluffy , whisking in moist clumps form dough . divide mixture among 4 plates . bake walnuts when linguine to make 2 minutes on each side . divide frosting can be prepared
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 362s 576ms/step - loss: 1.7009
# Epoch 13/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - loss: 1.6922
# generated text:
# recipe for " mule | in a food processor blend together the sugar ingredients , and then strain through fine - mesh sieve into a large metal sieve . refrigerate for a 10 - to roll , about 1 hour . yuca may be made 1 week ahead . keep chilled . in a food processor or blender blend in dry ingredients until smooth , about 1 minute . ( chocolate is smooth , add more water , water for dipping mixture , until pale and paste forms , about 1 minute . using the bowl , pour off the
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 358s 569ms/step - loss: 1.6922
# Epoch 14/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - loss: 1.6570
# generated text:
# recipe for four island chestnut - ounce vegetable crust with cilantro harissa sauce | whisk salt , crème fraîche , and coconut milk mix in melted butter . place mango sprigs in large resealable plastic bag . pour 1 tablespoon melted butter over tomatoes and 4 tablespoons ; season with salt . marinate vegetables 1 hour and up to 1 / 4 hours . have ready a food processor blend until smooth . season to taste with salt and pepper . garnish with avocado purée , yogurt wedges , dark rémoulade , and serve .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 346s 549ms/step - loss: 1.6570
# Epoch 15/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - loss: 1.6424
# generated text:
# recipe for herbed chicken toddy with pineapple , spinach and pea shoots | preheat broiler . remove pork from lemon bones and cut into 2 - inch pieces . reserve enough hot cooking water to cover rice . form indian onions , butter , and sage into a 1 - quart shallow round pan , leaving skins from pan , turning slices , some pods , 2 1 / 2 inches thick . arrange tomatoes , cover , and 1 1 / 2 cups water in a shallow dish and trim dark green parts of scissors to seal bone .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 327s 520ms/step - loss: 1.6424
# Epoch 16/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 1.6328
# generated text:
# recipe for lemon - topped mustard - balsamic sauce | whisk juice , 1 tablespoons sugar , and 1 / 2 teaspoon salt in small bowl ; let stand in 2 1 / 4 - to 6 - quart heavy saucepan until hot , stirring occasionally , about 10 minutes . add cranberries and next 3 ingredients . bring to boil in heavy saucepan . reduce heat to low . cover and cook until rice is tender . remove from heat , whisking well and let stand until surface of chocolate is smooth , about 1 hour . ( can
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 341s 542ms/step - loss: 1.6327
# Epoch 17/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 547ms/step - loss: 1.6149
# generated text:
# recipe for corn syrup | pour out vanilla , water , and syrup in a medium saucepan and trim excess to fit . cut into 1 / 2 - inch cubes and fill with cranberries , then bake mixture until vegetables are very tender and slightly caramelized , about 3 minutes . cool on a plate ; cool to room temperature . do ahead : can be made 1 month ahead . let stand at room temperature .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 346s 550ms/step - loss: 1.6149
# Epoch 18/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 1.5971
# generated text:
# recipe for mushroom and bell pepper strata | preheat oven to 400°f . spray baking sheet with nonstick spray . place beets in roasting pan . arrange bell peppers into small baking sheet and set aside . sprinkle pepper all over . simmer until chicken is soft , about 10 minutes . toss with half of mashed potatoes and peas . season with salt and black pepper .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 339s 539ms/step - loss: 1.5971
# Epoch 19/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - loss: 1.5860
# generated text:
# recipe for spiced tea torte | melt butter in heavy medium saucepan over medium heat . melt butter . add parsnips and calvados ; cover and cook until onions are tender , about 3 minutes . remove from heat . stir in cider . simmer until pears are tender , stirring occasionally , about 4 minutes . add pears ; boil to same skillet over medium heat until custard thickens , about 10 minutes . using electric milk is mace , beat cream cheese until smooth ; beat until smooth . add flour mixture , beating constantly until smooth ,
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 327s 521ms/step - loss: 1.5860
# Epoch 20/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - loss: 1.5691
# generated text:
# recipe for gin lemonade | in a cocktail shaker , finely whisk in water and stir well . strain the syrup into a medium saucepan ; add orange mixture to vanilla bean . ( if using as much water , and around the spoon to release it ) . pour the mixture into the saucepan and cover over the heat . cover and cook until chocolate is just tender and turns just simmer in the pot . add the sambaar powder , combine the strawberry [UNK] , and 6 ounce sliced raspberries with salt and a soft oats .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 326s 518ms/step - loss: 1.5691
# Epoch 21/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 1.5658
# generated text:
# recipe for celery root , herb , and potato salad | sprinkle fish with salt and pepper to taste ; available at asian markets . divide between 2 plates . wrap each shrimp and grilled seasonings in half . ( sushi butter can be made 1 day ahead . refrigerate . ) add 6 cups water and blend to blend . cover and refrigerate 5 hours . bring enough cold water to a boil and add potato ( optional water ) and bring to simmer , uncovered , until just tender , 3 to 4 minutes . drain well .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 324s 515ms/step - loss: 1.5658
# Epoch 22/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - loss: 1.5466
# generated text:
# recipe for corn bread pudding | mix flour , sugar , and salt in small bowl to blend . add 1 / 4 cup chocolate butter to vanilla bean . using on / off turns , blend nuts until moist crumbs form . preheat oven to 350°f . line baking sheet with parchment paper . place on small rimmed baking sheet ; bake until lightly browned on first , about 10 minutes . turn cupcakes out onto rack and cool completely . blend first 5 ingredients in small bowl . add 6 tablespoons vegetable oil mixture process . use fingertips
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 328s 521ms/step - loss: 1.5466
# Epoch 23/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - loss: 1.5416
# generated text:
# recipe for thai - style burgers | combine the vinegar and the cinnamon stick in the shallow serving bowl or and toss it with chicken and dressing keeps , covered . cover or freeze chilled , chilled or place several hours to allow the flavors to develop texture . don ' t loose when makes the will continue to serve it from again for the basil because mosaic .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 315s 500ms/step - loss: 1.5416
# Epoch 24/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - loss: 1.5285
# generated text:
# recipe for macerated [UNK] | cover donabe with 1 / 2 cup syrup cups . mix gelatin , sugar , salt , butter and sugar in a large pitcher over low heat and bring to a boil over a boil , reduce heat , a gentle simmer , stirring to dissolve sugar and water . do not add water as reduced to 3 / 4 cup , 15 to 20 minutes . whisk honey and cornstarch in a bowl until smooth and stir in vanilla segments . add strawberries and add to butterscotch and toast until few - to 40
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 322s 512ms/step - loss: 1.5285
# Epoch 25/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 1.5210
# generated text:
# recipe for baked salmon with potato - cheese pastry chips | peel , potatoes , and gently mash walnuts with a sour cream and milk is eggs and together in a food processor , fine , and chop together . mash coarsely with sour cream in a large bowl . melt butter in a large skillet over medium heat , stirring constantly . add breadcrumbs and tomato paste ; fry until both sides reaches 180°f ( or [UNK] ) , 5 seconds . add cream cheese and corn , tossing , and a swirl salt , pepper , and rice
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 321s 511ms/step - loss: 1.5210

# %%
# Save the final model
lstm.save("lstm.keras")

# %% [markdown]
# ## 6. Generate text using the LSTM

# %%
def print_probs(info, vocab, top_k=5):
    for i in info:
        print(f"\nPROMPT: {i['prompt']}")
        word_probs = i["word_probs"]
        p_sorted = np.sort(word_probs)[::-1][:top_k]
        i_sorted = np.argsort(word_probs)[::-1][:top_k]
        for p, i in zip(p_sorted, i_sorted):
            print(f"{vocab[i]}:   \t{np.round(100*p,2)}%")
        print("--------\n")

# %%
info = text_generator.generate(
    "recipe for roasted vegetables | chop 1 /", max_tokens=10, temperature=1.0
)
# Out:
# generated text:
# recipe for roasted vegetables | chop 1 / 4 cup

# %%
print_probs(info, vocab)
# Out:
# PROMPT: recipe for roasted vegetables | chop 1 /
# 2:   	51.72%
# 4:   	32.59%
# 3:   	12.56%
# 8:   	1.59%
# off:   	0.4%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4
# cup:   	75.12%
# teaspoon:   	6.09%
# of:   	5.28%
# -:   	3.66%
# ":   	2.08%
# --------

# %%
info = text_generator.generate(
    "recipe for roasted vegetables | chop 1 /", max_tokens=50, temperature=0.2
)
# Out:
# generated text:
# recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the salt , and the oil in a large bowl . add the remaining 1

# %%
print_probs(info, vocab)
# Out:
# PROMPT: recipe for roasted vegetables | chop 1 /
# 2:   	90.89%
# 4:   	9.03%
# 3:   	0.08%
# 8:   	0.0%
# off:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2
# cup:   	100.0%
# teaspoon:   	0.0%
# ":   	0.0%
# -:   	0.0%
# inch:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup
# all:   	53.03%
# bacon:   	36.96%
# garlic:   	5.61%
# water:   	2.17%
# of:   	0.88%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all
# the:   	95.32%
# of:   	4.55%
# over:   	0.13%
# but:   	0.0%
# onion:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the
# ingredients:   	99.87%
# onion:   	0.09%
# garlic:   	0.03%
# oil:   	0.0%
# juice:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients
# with:   	97.25%
# in:   	1.51%
# .:   	0.88%
# and:   	0.23%
# together:   	0.05%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with
# salt:   	73.53%
# the:   	15.53%
# oil:   	10.59%
# a:   	0.34%
# mortar:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt
# and:   	93.41%
# in:   	6.59%
# .:   	0.0%
# ;:   	0.0%
# for:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and
# pepper:   	100.0%
# let:   	0.0%
# stir:   	0.0%
# set:   	0.0%
# blend:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper
# in:   	99.34%
# to:   	0.38%
# .:   	0.28%
# and:   	0.0%
# into:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in
# a:   	100.0%
# the:   	0.0%
# oil:   	0.0%
# grinder:   	0.0%
# small:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a
# small:   	99.09%
# large:   	0.84%
# food:   	0.06%
# bowl:   	0.0%
# medium:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small
# bowl:   	98.15%
# saucepan:   	1.71%
# heavy:   	0.12%
# skillet:   	0.02%
# pan:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl
# .:   	99.99%
# ;:   	0.0%
# ,:   	0.0%
# and:   	0.0%
# to:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl .
# in:   	98.36%
# add:   	1.07%
# place:   	0.31%
# heat:   	0.17%
# let:   	0.06%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in
# a:   	100.0%
# another:   	0.0%
# large:   	0.0%
# small:   	0.0%
# the:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a
# large:   	65.71%
# small:   	33.69%
# bowl:   	0.53%
# heavy:   	0.03%
# medium:   	0.02%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small
# bowl:   	96.84%
# saucepan:   	2.77%
# heavy:   	0.39%
# skillet:   	0.0%
# sauté:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl
# stir:   	49.76%
# ,:   	35.28%
# whisk:   	14.47%
# combine:   	0.5%
# toss:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir
# together:   	100.0%
# in:   	0.0%
# the:   	0.0%
# -:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together
# the:   	99.92%
# all:   	0.05%
# with:   	0.02%
# garlic:   	0.0%
# flour:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the
# garlic:   	59.84%
# remaining:   	16.27%
# vinegar:   	13.97%
# butter:   	2.57%
# mustard:   	2.38%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic
# ,:   	55.38%
# paste:   	44.21%
# and:   	0.4%
# powder:   	0.0%
# mixture:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste
# ,:   	83.17%
# and:   	16.83%
# .:   	0.0%
# ingredients:   	0.0%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste ,
# the:   	99.97%
# oil:   	0.02%
# salt:   	0.01%
# garlic:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the
# garlic:   	64.12%
# oil:   	16.38%
# salt:   	9.01%
# mustard:   	5.83%
# lemon:   	1.89%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic
# ,:   	100.0%
# paste:   	0.0%
# and:   	0.0%
# powder:   	0.0%
# cloves:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic ,
# and:   	81.61%
# the:   	18.39%
# salt:   	0.0%
# 1:   	0.0%
# garlic:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the
# salt:   	92.2%
# thyme:   	2.71%
# garlic:   	2.21%
# oil:   	1.45%
# mustard:   	0.46%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the salt
# ,:   	100.0%
# and:   	0.0%
# .:   	0.0%
# if:   	0.0%
# to:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the salt ,
# and:   	98.1%
# the:   	1.9%
# pepper:   	0.0%
# oil:   	0.0%
# garlic:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the salt , and
# the:   	99.9%
# salt:   	0.07%
# pepper:   	0.02%
# 1:   	0.01%
# oil:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the salt , and the
# oil:   	65.62%
# salt:   	27.78%
# cayenne:   	3.9%
# garlic:   	1.1%
# mustard:   	0.96%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the salt , and the oil
# and:   	80.15%
# in:   	12.38%
# .:   	4.75%
# ,:   	2.56%
# until:   	0.16%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the salt , and the oil in
# a:   	100.0%
# the:   	0.0%
# an:   	0.0%
# another:   	0.0%
# large:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the salt , and the oil in a
# large:   	73.18%
# bowl:   	21.23%
# medium:   	5.17%
# small:   	0.4%
# slow:   	0.01%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the salt , and the oil in a large
# bowl:   	93.53%
# pot:   	5.85%
# skillet:   	0.57%
# saucepan:   	0.05%
# heavy:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the salt , and the oil in a large bowl
# .:   	86.23%
# ,:   	7.31%
# and:   	6.43%
# with:   	0.02%
# ;:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the salt , and the oil in a large bowl .
# add:   	99.88%
# in:   	0.12%
# place:   	0.0%
# heat:   	0.0%
# let:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the salt , and the oil in a large bowl . add
# the:   	100.0%
# to:   	0.0%
# 1:   	0.0%
# 2:   	0.0%
# a:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the salt , and the oil in a large bowl . add the
# onion:   	52.99%
# garlic:   	19.69%
# oil:   	16.12%
# remaining:   	6.72%
# chicken:   	2.67%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 2 cup all the ingredients with salt and pepper in a small bowl . in a small bowl stir together the garlic paste , the garlic , the salt , and the oil in a large bowl . add the remaining
# 2:   	60.11%
# 1:   	39.5%
# 3:   	0.26%
# ingredients:   	0.13%
# 4:   	0.0%
# --------

# %%
info = text_generator.generate(
    "recipe for chocolate ice cream |", max_tokens=7, temperature=1.0
)
print_probs(info, vocab)
# Out:
# generated text:
# recipe for chocolate ice cream | blend
#
#
# PROMPT: recipe for chocolate ice cream |
# whisk:   	13.11%
# combine:   	12.12%
# in:   	10.58%
# preheat:   	7.04%
# beat:   	6.75%
# --------

# %%
info = text_generator.generate(
    "recipe for chocolate ice cream |", max_tokens=500, temperature=0.2
)
print_probs(info, vocab)
# Out:
# generated text:
# recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then whisk in remaining 1 / 4 cup sugar and stir until smooth .
#
#
# PROMPT: recipe for chocolate ice cream |
# whisk:   	46.7%
# combine:   	31.53%
# in:   	16.03%
# preheat:   	2.09%
# beat:   	1.69%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk
# together:   	97.14%
# first:   	2.6%
# cream:   	0.19%
# eggs:   	0.03%
# flour:   	0.02%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together
# flour:   	53.86%
# cream:   	41.24%
# sugar:   	2.22%
# milk:   	2.06%
# yolks:   	0.61%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream
# ,:   	97.26%
# and:   	2.74%
# cheese:   	0.0%
# in:   	0.0%
# of:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream ,
# sugar:   	98.21%
# milk:   	1.57%
# cream:   	0.21%
# sour:   	0.01%
# yolks:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar
# ,:   	100.0%
# and:   	0.0%
# in:   	0.0%
# with:   	0.0%
# powder:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar ,
# and:   	99.7%
# sugar:   	0.26%
# salt:   	0.04%
# vanilla:   	0.0%
# lemon:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and
# salt:   	99.93%
# sugar:   	0.06%
# 1:   	0.01%
# vanilla:   	0.0%
# lemon:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt
# in:   	100.0%
# and:   	0.0%
# into:   	0.0%
# until:   	0.0%
# ,:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in
# a:   	100.0%
# processor:   	0.0%
# another:   	0.0%
# medium:   	0.0%
# an:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a
# bowl:   	91.03%
# large:   	4.11%
# small:   	2.08%
# medium:   	1.41%
# food:   	1.33%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl
# .:   	99.56%
# until:   	0.36%
# ,:   	0.04%
# and:   	0.03%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl .
# stir:   	52.72%
# whisk:   	35.07%
# add:   	10.95%
# in:   	0.55%
# pour:   	0.48%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir
# in:   	99.88%
# together:   	0.12%
# over:   	0.0%
# mixture:   	0.0%
# until:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in
# remaining:   	78.56%
# cream:   	9.83%
# vanilla:   	5.54%
# chocolate:   	1.77%
# pecans:   	0.93%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining
# 1:   	99.77%
# 2:   	0.09%
# ingredients:   	0.08%
# 3:   	0.05%
# tablespoon:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1
# /:   	100.0%
# 1:   	0.0%
# tablespoon:   	0.0%
# cup:   	0.0%
# teaspoon:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 /
# 4:   	73.47%
# 2:   	26.42%
# 3:   	0.11%
# 8:   	0.0%
# 6:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2
# cup:   	100.0%
# teaspoon:   	0.0%
# tablespoon:   	0.0%
# cups:   	0.0%
# tablespoons:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup
# sugar:   	100.0%
# water:   	0.0%
# cream:   	0.0%
# milk:   	0.0%
# granulated:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar
# and:   	94.22%
# ,:   	5.77%
# .:   	0.01%
# ;:   	0.0%
# until:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and
# 1:   	89.62%
# salt:   	10.25%
# vanilla:   	0.07%
# remaining:   	0.02%
# 2:   	0.01%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1
# /:   	99.98%
# cup:   	0.01%
# tablespoon:   	0.01%
# 1:   	0.0%
# teaspoon:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 /
# 4:   	51.33%
# 2:   	48.66%
# 3:   	0.01%
# 8:   	0.0%
# 6:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4
# cup:   	100.0%
# teaspoon:   	0.0%
# cups:   	0.0%
# tsp:   	0.0%
# -:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup
# water:   	88.16%
# sugar:   	11.73%
# cream:   	0.1%
# ice:   	0.0%
# milk:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water
# .:   	97.72%
# and:   	2.18%
# until:   	0.09%
# ,:   	0.0%
# to:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water .
# pour:   	21.73%
# add:   	18.95%
# stir:   	15.23%
# chill:   	14.51%
# whisk:   	11.95%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir
# in:   	99.48%
# together:   	0.51%
# over:   	0.01%
# mixture:   	0.0%
# until:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in
# remaining:   	93.86%
# vanilla:   	3.1%
# cream:   	1.18%
# 1:   	0.88%
# lemon:   	0.3%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining
# 1:   	99.9%
# 2:   	0.08%
# 3:   	0.02%
# ingredients:   	0.0%
# tablespoon:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1
# /:   	100.0%
# 1:   	0.0%
# tablespoon:   	0.0%
# cup:   	0.0%
# teaspoon:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 /
# 4:   	73.56%
# 2:   	26.31%
# 3:   	0.13%
# 8:   	0.0%
# 6:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4
# cup:   	100.0%
# teaspoon:   	0.0%
# cups:   	0.0%
# tablespoon:   	0.0%
# tsp:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup
# sugar:   	100.0%
# water:   	0.0%
# cream:   	0.0%
# milk:   	0.0%
# flour:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar
# and:   	94.61%
# ,:   	5.34%
# .:   	0.04%
# until:   	0.0%
# ;:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and
# 1:   	64.09%
# salt:   	35.76%
# vanilla:   	0.04%
# baking:   	0.04%
# remaining:   	0.03%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt
# .:   	67.68%
# and:   	32.32%
# to:   	0.0%
# ,:   	0.0%
# ;:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt .
# beat:   	44.3%
# pour:   	15.43%
# let:   	15.03%
# add:   	8.08%
# cover:   	6.78%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add
# butter:   	66.93%
# remaining:   	19.81%
# milk:   	10.22%
# 1:   	1.64%
# cream:   	0.38%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk
# mixture:   	97.1%
# and:   	2.66%
# to:   	0.12%
# ,:   	0.11%
# in:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture
# to:   	100.0%
# and:   	0.0%
# in:   	0.0%
# ,:   	0.0%
# until:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to
# a:   	99.24%
# milk:   	0.27%
# flour:   	0.2%
# dry:   	0.15%
# remaining:   	0.08%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a
# boil:   	98.77%
# bowl:   	0.65%
# simmer:   	0.53%
# whisk:   	0.02%
# stream:   	0.01%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil
# in:   	79.7%
# ,:   	19.51%
# over:   	0.79%
# .:   	0.0%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil ,
# whisking:   	79.35%
# stirring:   	19.71%
# then:   	0.94%
# scraping:   	0.0%
# and:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking
# until:   	84.85%
# constantly:   	15.14%
# ,:   	0.01%
# .:   	0.0%
# occasionally:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until
# smooth:   	52.62%
# sugar:   	24.69%
# combined:   	22.26%
# mixture:   	0.38%
# incorporated:   	0.04%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar
# is:   	100.0%
# has:   	0.0%
# dissolves:   	0.0%
# and:   	0.0%
# melts:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is
# dissolved:   	100.0%
# melted:   	0.0%
# thick:   	0.0%
# combined:   	0.0%
# incorporated:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved
# .:   	89.33%
# ,:   	10.67%
# and:   	0.0%
# ;:   	0.0%
# (:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved ,
# then:   	89.11%
# and:   	10.89%
# about:   	0.0%
# add:   	0.0%
# 3:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then
# whisk:   	55.28%
# stir:   	34.18%
# add:   	10.39%
# simmer:   	0.06%
# transfer:   	0.05%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk
# in:   	100.0%
# into:   	0.0%
# milk:   	0.0%
# until:   	0.0%
# to:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in
# milk:   	61.31%
# remaining:   	21.81%
# vanilla:   	14.57%
# cream:   	1.35%
# 1:   	0.5%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk
# .:   	86.36%
# and:   	8.52%
# ,:   	4.8%
# mixture:   	0.31%
# until:   	0.01%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk .
# whisk:   	25.67%
# cook:   	23.34%
# add:   	21.58%
# stir:   	19.42%
# pour:   	5.38%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook
# custard:   	62.98%
# mixture:   	17.42%
# over:   	17.26%
# ,:   	2.14%
# roux:   	0.18%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard
# over:   	65.03%
# in:   	34.97%
# until:   	0.0%
# ,:   	0.0%
# through:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over
# moderate:   	99.0%
# moderately:   	1.0%
# medium:   	0.0%
# low:   	0.0%
# high:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate
# heat:   	100.0%
# and:   	0.0%
# ,:   	0.0%
# until:   	0.0%
# water:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat
# ,:   	99.94%
# until:   	0.06%
# and:   	0.0%
# just:   	0.0%
# .:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat ,
# stirring:   	99.74%
# whisking:   	0.26%
# covered:   	0.0%
# undisturbed:   	0.0%
# then:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring
# ,:   	67.9%
# occasionally:   	27.99%
# constantly:   	4.1%
# frequently:   	0.01%
# until:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring ,
# until:   	100.0%
# 1:   	0.0%
# and:   	0.0%
# 3:   	0.0%
# 2:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until
# thickened:   	47.22%
# sugar:   	30.58%
# mixture:   	10.16%
# gelatin:   	6.19%
# custard:   	3.78%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin
# is:   	100.0%
# has:   	0.0%
# mixture:   	0.0%
# begins:   	0.0%
# softens:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is
# dissolved:   	100.0%
# melted:   	0.0%
# absorbed:   	0.0%
# thickened:   	0.0%
# reduced:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved
# ,:   	82.91%
# .:   	16.63%
# and:   	0.46%
# (:   	0.0%
# ;:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved ,
# about:   	68.28%
# then:   	27.76%
# whisking:   	3.8%
# and:   	0.12%
# 3:   	0.04%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then
# whisk:   	71.45%
# simmer:   	22.2%
# stir:   	6.12%
# transfer:   	0.17%
# cool:   	0.04%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then whisk
# in:   	100.0%
# into:   	0.0%
# until:   	0.0%
# to:   	0.0%
# constantly:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then whisk in
# remaining:   	53.02%
# cream:   	41.68%
# milk:   	2.98%
# vanilla:   	1.74%
# 1:   	0.36%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then whisk in remaining
# 1:   	99.55%
# 2:   	0.37%
# 3:   	0.05%
# tablespoon:   	0.03%
# ingredients:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then whisk in remaining 1
# /:   	99.99%
# tablespoon:   	0.01%
# 1:   	0.0%
# cup:   	0.0%
# teaspoon:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then whisk in remaining 1 /
# 4:   	88.32%
# 2:   	11.64%
# 3:   	0.04%
# 8:   	0.0%
# 6:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then whisk in remaining 1 / 4
# cup:   	100.0%
# teaspoon:   	0.0%
# tablespoon:   	0.0%
# cups:   	0.0%
# tsp:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then whisk in remaining 1 / 4 cup
# sugar:   	98.54%
# cream:   	1.31%
# milk:   	0.11%
# water:   	0.05%
# plus:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then whisk in remaining 1 / 4 cup sugar
# and:   	54.04%
# until:   	22.88%
# .:   	12.11%
# ,:   	10.97%
# ;:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then whisk in remaining 1 / 4 cup sugar and
# simmer:   	37.27%
# stir:   	31.68%
# whisk:   	22.07%
# salt:   	4.12%
# cook:   	3.6%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then whisk in remaining 1 / 4 cup sugar and stir
# until:   	99.77%
# .:   	0.21%
# in:   	0.01%
# to:   	0.0%
# just:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then whisk in remaining 1 / 4 cup sugar and stir until
# smooth:   	48.89%
# combined:   	38.68%
# incorporated:   	8.71%
# sugar:   	2.33%
# mixture:   	1.21%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then whisk in remaining 1 / 4 cup sugar and stir until smooth
# .:   	100.0%
# ,:   	0.0%
# and:   	0.0%
# (:   	0.0%
# ;:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | whisk together cream , sugar , and salt in a bowl . stir in remaining 1 / 2 cup sugar and 1 / 4 cup water . stir in remaining 1 / 4 cup sugar and salt . add milk mixture to a boil , whisking until sugar is dissolved , then whisk in milk . cook custard over moderate heat , stirring , until gelatin is dissolved , then whisk in remaining 1 / 4 cup sugar and stir until smooth .
# :   	71.7%
# stir:   	26.87%
# serve:   	0.66%
# remove:   	0.22%
# whisk:   	0.19%
# --------

# %%
info = text_generator.generate("recipe for chicken", max_tokens=100, temperature=0.5)

print_probs(info, vocab)
# Out:
# generated text:
# recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about 30 minutes . do ahead : can be made 1 day ahead . cover
#
#
# PROMPT: recipe for chicken
# with:   	40.86%
# and:   	38.03%
# ,:   	11.93%
# stock:   	4.22%
# breasts:   	1.19%
# --------
#
#
# PROMPT: recipe for chicken with
# tomato:   	11.59%
# sausage:   	6.75%
# green:   	6.74%
# red:   	6.68%
# bacon:   	6.29%
# --------
#
#
# PROMPT: recipe for chicken with olives
# ,:   	54.51%
# and:   	45.14%
# |:   	0.34%
# with:   	0.0%
# .:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives ,
# olives:   	19.2%
# tomatoes:   	18.5%
# bacon:   	10.56%
# tomato:   	6.86%
# garlic:   	6.34%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel
# ,:   	59.48%
# and:   	40.47%
# -:   	0.03%
# greens:   	0.01%
# root:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel ,
# and:   	99.91%
# garlic:   	0.01%
# olives:   	0.01%
# red:   	0.01%
# tomatoes:   	0.01%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and
# bacon:   	11.56%
# garlic:   	9.51%
# onions:   	4.95%
# red:   	4.45%
# feta:   	3.36%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon
# |:   	99.97%
# -:   	0.01%
# sauce:   	0.0%
# in:   	0.0%
# stuffing:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon |
# preheat:   	78.44%
# heat:   	6.35%
# in:   	4.9%
# cook:   	4.12%
# combine:   	1.24%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook
# bacon:   	72.14%
# onion:   	19.5%
# potatoes:   	1.81%
# garlic:   	1.57%
# onions:   	1.41%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon
# in:   	99.91%
# ,:   	0.05%
# and:   	0.02%
# over:   	0.01%
# according:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in
# heavy:   	50.55%
# large:   	45.09%
# a:   	2.22%
# medium:   	1.47%
# pot:   	0.3%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large
# pot:   	86.19%
# skillet:   	10.09%
# nonstick:   	1.9%
# saucepan:   	1.54%
# deep:   	0.12%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot
# of:   	91.32%
# over:   	8.67%
# to:   	0.0%
# with:   	0.0%
# until:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of
# boiling:   	99.98%
# salted:   	0.01%
# oil:   	0.0%
# heavy:   	0.0%
# skillet:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling
# salted:   	99.78%
# water:   	0.22%
# boiling:   	0.0%
# over:   	0.0%
# -:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted
# water:   	100.0%
# boiling:   	0.0%
# oil:   	0.0%
# salted:   	0.0%
# butter:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water
# until:   	99.95%
# ,:   	0.02%
# over:   	0.01%
# to:   	0.01%
# 2:   	0.01%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until
# crisp:   	65.98%
# just:   	16.67%
# tender:   	16.65%
# very:   	0.27%
# almost:   	0.14%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender
# but:   	92.05%
# ,:   	7.89%
# when:   	0.03%
# .:   	0.02%
# and:   	0.02%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but
# still:   	97.76%
# not:   	2.22%
# rendered:   	0.0%
# salt:   	0.0%
# browning:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still
# firm:   	89.56%
# crisp:   	7.42%
# bright:   	2.78%
# intact:   	0.03%
# dry:   	0.03%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm
# to:   	99.97%
# .:   	0.02%
# ,:   	0.01%
# but:   	0.0%
# when:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to
# bite:   	99.89%
# touch:   	0.09%
# about:   	0.01%
# crisp:   	0.0%
# color:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite
# ,:   	57.88%
# .:   	41.84%
# ;:   	0.18%
# and:   	0.07%
# (:   	0.01%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite .
# drain:   	99.78%
# transfer:   	0.13%
# add:   	0.02%
# meanwhile:   	0.02%
# remove:   	0.01%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain
# .:   	83.74%
# ;:   	9.5%
# ,:   	2.68%
# well:   	2.54%
# and:   	0.67%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ;
# transfer:   	56.45%
# return:   	16.69%
# reserve:   	7.82%
# cool:   	3.42%
# pat:   	3.08%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer
# to:   	99.82%
# with:   	0.08%
# bacon:   	0.07%
# potatoes:   	0.01%
# vegetables:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to
# bowl:   	43.04%
# paper:   	34.01%
# large:   	21.67%
# medium:   	0.53%
# plate:   	0.22%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper
# towels:   	99.97%
# towel:   	0.03%
# towel–lined:   	0.0%
# .:   	0.0%
# -:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels
# to:   	72.94%
# .:   	25.09%
# and:   	1.37%
# ;:   	0.47%
# ,:   	0.1%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels .
# drain:   	83.28%
# add:   	7.31%
# meanwhile:   	3.5%
# transfer:   	1.54%
# remove:   	0.7%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain
# potatoes:   	25.96%
# .:   	17.25%
# well:   	15.06%
# beans:   	8.39%
# ;:   	6.56%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans
# .:   	55.84%
# and:   	17.19%
# ,:   	14.59%
# ;:   	10.6%
# in:   	1.17%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and
# pat:   	37.59%
# reserve:   	15.63%
# rinse:   	11.2%
# cut:   	7.24%
# return:   	5.35%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse
# under:   	96.46%
# with:   	2.26%
# well:   	0.91%
# .:   	0.16%
# dry:   	0.04%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under
# cold:   	99.99%
# cool:   	0.01%
# .:   	0.0%
# water:   	0.0%
# running:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold
# water:   	99.27%
# running:   	0.53%
# .:   	0.2%
# cold:   	0.0%
# salted:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water
# .:   	86.93%
# to:   	8.96%
# until:   	2.17%
# and:   	1.08%
# ;:   	0.65%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water .
# drain:   	93.4%
# transfer:   	4.08%
# return:   	0.57%
# place:   	0.29%
# heat:   	0.21%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain
# well:   	49.51%
# .:   	18.47%
# ;:   	11.71%
# beans:   	10.25%
# and:   	2.35%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well
# .:   	90.14%
# and:   	5.11%
# ;:   	3.75%
# ,:   	0.71%
# in:   	0.27%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well .
# transfer:   	32.96%
# return:   	9.79%
# add:   	8.98%
# (:   	6.69%
# place:   	6.12%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place
# potatoes:   	37.84%
# beans:   	15.36%
# in:   	9.35%
# tomatoes:   	4.72%
# bacon:   	3.55%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1
# /:   	64.07%
# cup:   	17.08%
# tablespoon:   	7.01%
# 1:   	6.76%
# potato:   	0.99%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup
# water:   	25.85%
# warm:   	13.04%
# beans:   	10.54%
# corn:   	6.94%
# cream:   	6.33%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans
# in:   	96.83%
# and:   	0.92%
# ,:   	0.87%
# into:   	0.57%
# with:   	0.42%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in
# large:   	90.1%
# medium:   	3.13%
# bowl:   	2.68%
# processor:   	1.92%
# small:   	1.19%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large
# bowl:   	99.24%
# saucepan:   	0.51%
# pot:   	0.21%
# skillet:   	0.01%
# sieve:   	0.01%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan
# .:   	74.36%
# of:   	20.71%
# ;:   	3.23%
# and:   	0.65%
# ,:   	0.45%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan .
# add:   	41.92%
# bring:   	21.88%
# stir:   	19.79%
# boil:   	9.67%
# cover:   	1.56%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add
# enough:   	45.92%
# 1:   	15.28%
# remaining:   	9.5%
# 2:   	5.36%
# potatoes:   	3.21%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough
# water:   	50.69%
# cold:   	37.49%
# hot:   	9.06%
# boiling:   	0.82%
# reserved:   	0.54%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water
# to:   	99.97%
# by:   	0.03%
# and:   	0.0%
# at:   	0.0%
# ,:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to
# cover:   	91.24%
# boil:   	6.92%
# reach:   	0.67%
# come:   	0.43%
# pot:   	0.23%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover
# by:   	95.52%
# .:   	1.01%
# and:   	0.98%
# mixture:   	0.85%
# ,:   	0.58%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by
# 2:   	69.4%
# 1:   	24.74%
# 3:   	5.32%
# 4:   	0.26%
# half:   	0.12%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2
# inches:   	99.57%
# cups:   	0.16%
# 1:   	0.12%
# to:   	0.08%
# -:   	0.02%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches
# .:   	90.76%
# and:   	4.57%
# to:   	3.2%
# ;:   	0.96%
# (:   	0.15%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches .
# bring:   	90.12%
# cover:   	6.38%
# boil:   	2.14%
# simmer:   	0.62%
# let:   	0.27%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring
# to:   	99.8%
# mixture:   	0.13%
# water:   	0.02%
# pan:   	0.01%
# just:   	0.01%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to
# boil:   	96.39%
# simmer:   	3.61%
# a:   	0.0%
# pot:   	0.0%
# room:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil
# .:   	79.5%
# ,:   	18.32%
# ;:   	0.92%
# over:   	0.8%
# and:   	0.4%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil .
# reduce:   	90.67%
# add:   	3.8%
# remove:   	2.64%
# cover:   	2.2%
# boil:   	0.2%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce
# heat:   	100.0%
# oven:   	0.0%
# water:   	0.0%
# temperature:   	0.0%
# broth:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat
# to:   	93.28%
# and:   	5.23%
# ;:   	1.2%
# ,:   	0.23%
# .:   	0.05%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to
# medium:   	90.68%
# low:   	9.25%
# simmer:   	0.02%
# boiling:   	0.01%
# 350°f:   	0.01%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium
# -:   	88.33%
# and:   	8.2%
# ;:   	1.68%
# .:   	1.48%
# ,:   	0.27%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium -
# low:   	99.58%
# high:   	0.42%
# hot:   	0.0%
# medium:   	0.0%
# simmer:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low
# and:   	62.73%
# .:   	17.2%
# ;:   	12.04%
# ,:   	8.01%
# heat:   	0.01%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ;
# simmer:   	83.0%
# cover:   	15.94%
# boil:   	0.53%
# add:   	0.18%
# reduce:   	0.13%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer
# until:   	88.47%
# uncovered:   	10.57%
# 15:   	0.24%
# 10:   	0.2%
# 5:   	0.17%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until
# potatoes:   	24.5%
# liquid:   	15.94%
# vegetables:   	13.74%
# tender:   	9.26%
# reduced:   	4.24%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid
# is:   	97.65%
# thickens:   	2.07%
# evaporates:   	0.23%
# and:   	0.02%
# has:   	0.01%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is
# reduced:   	64.79%
# absorbed:   	31.84%
# almost:   	1.89%
# very:   	0.87%
# tender:   	0.15%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced
# to:   	99.52%
# by:   	0.47%
# and:   	0.0%
# ,:   	0.0%
# slightly:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to
# 1:   	79.62%
# 3:   	12.23%
# 2:   	4.53%
# 4:   	1.23%
# glaze:   	0.78%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1
# /:   	54.84%
# 1:   	40.11%
# cup:   	4.82%
# tablespoon:   	0.1%
# inch:   	0.08%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 /
# 2:   	68.56%
# 4:   	25.25%
# 3:   	6.05%
# 8:   	0.14%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2
# cup:   	99.92%
# cups:   	0.06%
# 1:   	0.01%
# -:   	0.01%
# teaspoon:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup
# ,:   	99.74%
# .:   	0.13%
# and:   	0.07%
# (:   	0.03%
# ;:   	0.01%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup ,
# about:   	99.18%
# stirring:   	0.81%
# whisking:   	0.0%
# scraping:   	0.0%
# adding:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about
# 15:   	25.26%
# 10:   	19.58%
# 30:   	17.68%
# 20:   	17.31%
# 5:   	7.94%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about 30
# minutes:   	99.99%
# seconds:   	0.01%
# to:   	0.0%
# -:   	0.0%
# cups:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about 30 minutes
# .:   	99.99%
# ;:   	0.0%
# (:   	0.0%
# ,:   	0.0%
# and:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about 30 minutes .
# meanwhile:   	13.4%
# transfer:   	12.87%
# remove:   	10.84%
# (:   	10.45%
# season:   	10.08%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about 30 minutes . do
# ahead:   	99.99%
# not:   	0.01%
# can:   	0.0%
# will:   	0.0%
# liquid:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about 30 minutes . do ahead
# ::   	86.12%
# can:   	13.78%
# sauce:   	0.08%
# eggs:   	0.0%
# syrup:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about 30 minutes . do ahead :
# can:   	99.63%
# sauce:   	0.3%
# rice:   	0.01%
# beets:   	0.01%
# fresh:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about 30 minutes . do ahead : can
# be:   	100.0%
# made:   	0.0%
# available:   	0.0%
# do:   	0.0%
# ahead:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about 30 minutes . do ahead : can be
# made:   	99.91%
# prepared:   	0.09%
# found:   	0.0%
# large:   	0.0%
# baked:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about 30 minutes . do ahead : can be made
# 1:   	78.52%
# 2:   	19.0%
# 3:   	1.4%
# 4:   	0.79%
# 6:   	0.15%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about 30 minutes . do ahead : can be made 1
# day:   	99.54%
# week:   	0.45%
# hour:   	0.01%
# month:   	0.0%
# days:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about 30 minutes . do ahead : can be made 1 day
# ahead:   	100.0%
# .:   	0.0%
# up:   	0.0%
# in:   	0.0%
# to:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about 30 minutes . do ahead : can be made 1 day ahead
# .:   	99.96%
# ;:   	0.04%
# and:   	0.0%
# ,:   	0.0%
# (:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken with olives , fennel , and bacon | cook bacon in large pot of boiling salted water until tender but still firm to bite . drain ; transfer to paper towels . drain beans and rinse under cold water . drain well . place 1 cup beans in large saucepan . add enough water to cover by 2 inches . bring to boil . reduce heat to medium - low ; simmer until liquid is reduced to 1 / 2 cup , about 30 minutes . do ahead : can be made 1 day ahead .
# cover:   	85.06%
# cool:   	14.63%
# chill:   	0.17%
# refrigerate:   	0.08%
# let:   	0.03%
# --------

# %%
info = text_generator.generate("recipe for chicken", max_tokens=100, temperature=0.8)

print_probs(info, vocab)
# Out:
# generated text:
# recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring occasionally , until beans are wilted and translucent , about 5 minutes . remove
#
#
# PROMPT: recipe for chicken
# with:   	26.28%
# and:   	25.13%
# ,:   	12.18%
# stock:   	6.36%
# breasts:   	2.89%
# --------
#
#
# PROMPT: recipe for chicken and
# mushroom:   	10.91%
# tomato:   	6.49%
# sausage:   	4.58%
# vegetable:   	3.61%
# noodle:   	3.45%
# --------
#
#
# PROMPT: recipe for chicken and scallops
# with:   	58.19%
# on:   	4.56%
# salad:   	3.9%
# stew:   	2.52%
# stir:   	2.39%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup
# |:   	83.16%
# with:   	16.63%
# in:   	0.11%
# [UNK]:   	0.01%
# on:   	0.01%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup |
# heat:   	44.14%
# in:   	13.25%
# melt:   	8.16%
# bring:   	7.42%
# cook:   	6.37%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate
# garlic:   	9.98%
# the:   	8.15%
# celery:   	6.78%
# rice:   	5.07%
# potatoes:   	5.02%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic
# cloves:   	83.44%
# and:   	11.37%
# into:   	1.17%
# ,:   	0.9%
# in:   	0.88%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves
# ,:   	39.09%
# and:   	32.87%
# into:   	11.22%
# .:   	5.83%
# in:   	3.99%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves ,
# and:   	19.79%
# then:   	16.68%
# bay:   	13.63%
# thyme:   	7.47%
# garlic:   	6.36%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and
# bay:   	17.97%
# seeds:   	7.98%
# garlic:   	7.7%
# mash:   	3.16%
# 1:   	2.54%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme
# .:   	19.65%
# sprigs:   	19.45%
# in:   	14.78%
# into:   	14.41%
# sprig:   	10.13%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig
# in:   	33.65%
# into:   	31.75%
# ,:   	14.39%
# .:   	7.39%
# and:   	7.06%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into
# a:   	43.45%
# 1:   	6.74%
# each:   	6.13%
# the:   	5.49%
# large:   	3.03%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan
# .:   	77.62%
# and:   	11.29%
# (:   	3.26%
# ;:   	2.21%
# ,:   	1.18%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan .
# heat:   	33.33%
# in:   	16.12%
# place:   	10.4%
# cut:   	3.33%
# add:   	3.13%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat
# oil:   	35.02%
# 1:   	25.71%
# 2:   	13.89%
# a:   	7.21%
# 3:   	4.16%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3
# tablespoons:   	80.48%
# /:   	11.84%
# inches:   	3.27%
# tbsp:   	1.88%
# teaspoons:   	0.44%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 /
# 4:   	84.79%
# 2:   	9.61%
# 3:   	4.68%
# 8:   	0.7%
# 6:   	0.06%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4
# cup:   	90.46%
# teaspoon:   	3.6%
# inch:   	2.18%
# tablespoon:   	1.11%
# tsp:   	0.72%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup
# oil:   	82.05%
# olive:   	5.45%
# water:   	3.78%
# cooking:   	1.8%
# vegetable:   	1.64%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter
# in:   	87.05%
# ,:   	3.53%
# over:   	2.9%
# and:   	1.99%
# with:   	1.19%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in
# a:   	49.98%
# heavy:   	21.13%
# large:   	12.56%
# medium:   	6.8%
# same:   	3.38%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same
# pot:   	42.99%
# skillet:   	29.22%
# saucepan:   	14.25%
# wok:   	3.42%
# large:   	3.08%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok
# or:   	90.96%
# over:   	2.25%
# until:   	2.13%
# ,:   	1.72%
# and:   	1.39%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or
# large:   	27.18%
# heavy:   	24.24%
# wok:   	15.0%
# skillet:   	12.31%
# dutch:   	8.84%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok
# over:   	37.1%
# or:   	34.51%
# ,:   	13.51%
# until:   	4.59%
# and:   	3.98%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over
# medium:   	51.62%
# high:   	46.06%
# low:   	1.31%
# moderately:   	0.57%
# moderate:   	0.37%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high
# heat:   	99.31%
# until:   	0.46%
# ,:   	0.12%
# .:   	0.05%
# and:   	0.02%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat
# until:   	59.92%
# .:   	27.19%
# ,:   	11.89%
# and:   	0.38%
# ;:   	0.2%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat .
# add:   	92.92%
# cook:   	1.47%
# working:   	1.17%
# reduce:   	0.75%
# stir:   	0.59%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add
# onion:   	22.85%
# garlic:   	14.5%
# chicken:   	9.53%
# onions:   	7.58%
# shallots:   	5.41%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown
# sugar:   	87.24%
# ,:   	3.43%
# and:   	1.81%
# rice:   	1.54%
# onions:   	0.56%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar
# and:   	51.71%
# ,:   	40.24%
# ;:   	6.16%
# .:   	0.73%
# to:   	0.26%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and
# cook:   	40.15%
# stir:   	19.81%
# sauté:   	18.24%
# bring:   	2.3%
# garlic:   	1.96%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir
# -:   	43.52%
# until:   	28.36%
# to:   	14.36%
# 1:   	5.63%
# constantly:   	1.27%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir -
# fry:   	99.82%
# to:   	0.06%
# brown:   	0.02%
# sugar:   	0.02%
# minute:   	0.01%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry
# until:   	80.49%
# 1:   	5.14%
# ,:   	3.98%
# 2:   	2.77%
# for:   	2.04%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until
# fragrant:   	39.21%
# golden:   	16.53%
# browned:   	6.96%
# brown:   	6.59%
# aromatic:   	3.2%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture
# is:   	79.74%
# begins:   	13.6%
# registers:   	1.48%
# turns:   	1.28%
# starts:   	0.77%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins
# to:   	99.99%
# slightly:   	0.0%
# crisping:   	0.0%
# lightly:   	0.0%
# completely:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to
# brown:   	38.99%
# turn:   	13.2%
# pop:   	11.4%
# soften:   	5.43%
# smoke:   	3.95%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown
# ,:   	79.58%
# .:   	14.36%
# and:   	3.51%
# on:   	0.64%
# (:   	0.26%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown ,
# about:   	94.85%
# 5–8:   	0.73%
# 1:   	0.64%
# 8–10:   	0.51%
# 3:   	0.4%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning
# occasionally:   	42.59%
# once:   	23.43%
# frequently:   	18.93%
# often:   	3.25%
# ,:   	2.07%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once
# ,:   	64.76%
# or:   	17.04%
# .:   	13.2%
# and:   	2.4%
# with:   	0.74%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once ,
# about:   	77.93%
# until:   	6.83%
# 1:   	2.81%
# 3:   	2.63%
# 5:   	2.59%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about
# 5:   	30.65%
# 3:   	15.34%
# 4:   	10.48%
# 2:   	9.62%
# 1:   	7.35%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6
# minutes:   	99.89%
# to:   	0.09%
# seconds:   	0.01%
# hours:   	0.0%
# -:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes
# .:   	98.62%
# (:   	0.35%
# total:   	0.3%
# ;:   	0.26%
# ,:   	0.16%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes .
# add:   	83.55%
# transfer:   	4.89%
# stir:   	3.44%
# remove:   	1.96%
# reduce:   	1.66%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add
# garlic:   	11.98%
# wine:   	8.51%
# tomatoes:   	8.32%
# 1:   	4.45%
# flour:   	3.58%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes
# and:   	39.62%
# ,:   	32.32%
# with:   	23.07%
# ;:   	3.14%
# .:   	0.95%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes ,
# garlic:   	15.02%
# onion:   	9.45%
# tomatoes:   	5.05%
# wine:   	4.66%
# thyme:   	2.77%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion
# ,:   	93.87%
# and:   	5.52%
# powder:   	0.22%
# paste:   	0.12%
# mixture:   	0.08%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and
# garlic:   	52.17%
# 1:   	2.83%
# tomatoes:   	2.75%
# remaining:   	2.47%
# onion:   	2.46%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic
# and:   	38.73%
# ,:   	32.22%
# ;:   	8.96%
# .:   	8.58%
# to:   	4.52%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ;
# cook:   	38.01%
# sauté:   	30.4%
# stir:   	13.32%
# season:   	5.94%
# bring:   	2.15%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté
# until:   	58.85%
# 1:   	15.16%
# 2:   	9.99%
# 5:   	5.63%
# 3:   	3.41%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1
# minute:   	99.07%
# /:   	0.39%
# 1:   	0.24%
# tablespoon:   	0.14%
# to:   	0.04%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute
# .:   	96.99%
# ,:   	0.79%
# longer:   	0.77%
# ;:   	0.77%
# more:   	0.22%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute .
# add:   	88.8%
# stir:   	4.36%
# mix:   	1.48%
# season:   	1.28%
# transfer:   	0.72%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add
# tomatoes:   	10.91%
# wine:   	9.51%
# broth:   	8.09%
# garlic:   	4.76%
# stock:   	4.64%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork
# and:   	52.31%
# ,:   	31.68%
# ;:   	6.91%
# chops:   	1.79%
# .:   	1.53%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork ,
# tomatoes:   	10.89%
# broth:   	5.2%
# garlic:   	4.9%
# onion:   	4.69%
# wine:   	3.33%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining
# 1:   	46.04%
# 2:   	24.07%
# 3:   	7.39%
# ingredients:   	2.79%
# garlic:   	1.79%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1
# tablespoon:   	38.84%
# /:   	38.02%
# teaspoon:   	12.71%
# cup:   	8.36%
# 1:   	1.08%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 /
# 4:   	53.17%
# 2:   	37.86%
# 3:   	8.52%
# 8:   	0.31%
# 6:   	0.06%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2
# cup:   	62.69%
# teaspoon:   	29.44%
# tablespoon:   	4.02%
# tsp:   	3.32%
# cups:   	0.1%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup
# water:   	26.39%
# cilantro:   	11.56%
# oil:   	6.73%
# broth:   	5.02%
# parsley:   	3.84%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved
# cooking:   	17.32%
# juice:   	6.02%
# liquid:   	5.91%
# broth:   	4.61%
# stock:   	3.53%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice
# ,:   	84.3%
# and:   	9.32%
# concentrate:   	1.55%
# from:   	1.4%
# sauce:   	1.37%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice ,
# and:   	76.24%
# 1:   	3.37%
# wine:   	2.78%
# 2:   	1.29%
# tomato:   	0.94%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2
# tablespoons:   	46.34%
# cups:   	35.1%
# teaspoons:   	7.98%
# /:   	2.67%
# cup:   	1.86%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons
# water:   	8.95%
# parsley:   	7.63%
# soy:   	7.21%
# cilantro:   	7.09%
# thyme:   	6.72%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro
# ,:   	87.6%
# and:   	9.14%
# .:   	1.84%
# stems:   	0.82%
# ;:   	0.24%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro ,
# and:   	76.07%
# 1:   	8.74%
# 2:   	3.14%
# 3:   	2.04%
# garlic:   	0.62%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and
# 1:   	35.98%
# 2:   	21.1%
# 3:   	6.75%
# remaining:   	5.29%
# garlic:   	2.17%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2
# cups:   	49.89%
# tablespoons:   	31.09%
# teaspoons:   	11.49%
# 1:   	1.95%
# /:   	1.5%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups
# water:   	67.47%
# broth:   	18.44%
# stock:   	5.12%
# rice:   	0.71%
# chicken:   	0.51%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water
# and:   	46.03%
# .:   	31.58%
# ;:   	10.8%
# ,:   	7.98%
# to:   	2.7%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and
# simmer:   	40.61%
# bring:   	37.29%
# boil:   	6.83%
# cook:   	6.47%
# stir:   	5.49%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook
# ,:   	75.77%
# until:   	19.45%
# over:   	2.66%
# 1:   	0.31%
# 5:   	0.2%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook ,
# stirring:   	90.82%
# uncovered:   	2.52%
# covered:   	2.35%
# partially:   	1.42%
# scraping:   	1.15%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring
# occasionally:   	62.62%
# ,:   	19.03%
# often:   	9.44%
# frequently:   	5.9%
# constantly:   	2.46%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring occasionally
# ,:   	99.43%
# and:   	0.3%
# .:   	0.13%
# until:   	0.03%
# if:   	0.02%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring occasionally ,
# until:   	85.53%
# 1:   	4.13%
# 3:   	1.9%
# 2:   	1.72%
# about:   	1.59%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring occasionally , until
# liquid:   	15.93%
# sauce:   	12.18%
# vegetables:   	8.46%
# chicken:   	4.8%
# reduced:   	4.53%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring occasionally , until beans
# are:   	96.92%
# and:   	0.94%
# begin:   	0.65%
# have:   	0.54%
# start:   	0.26%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring occasionally , until beans are
# tender:   	50.1%
# very:   	16.0%
# just:   	9.45%
# almost:   	6.58%
# soft:   	3.92%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring occasionally , until beans are wilted
# ,:   	69.62%
# and:   	24.34%
# but:   	2.94%
# .:   	2.13%
# -:   	0.17%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring occasionally , until beans are wilted and
# tender:   	24.37%
# liquid:   	15.29%
# reduced:   	6.17%
# sauce:   	4.91%
# vegetables:   	4.4%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring occasionally , until beans are wilted and translucent
# ,:   	94.48%
# and:   	3.15%
# .:   	1.5%
# in:   	0.39%
# but:   	0.2%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring occasionally , until beans are wilted and translucent ,
# about:   	84.17%
# 3:   	2.75%
# 8:   	2.51%
# 10:   	1.5%
# 1:   	1.41%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring occasionally , until beans are wilted and translucent , about
# 5:   	26.3%
# 10:   	13.85%
# 3:   	10.28%
# 2:   	9.86%
# 1:   	7.31%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring occasionally , until beans are wilted and translucent , about 5
# minutes:   	99.91%
# hours:   	0.05%
# to:   	0.02%
# -:   	0.01%
# cups:   	0.0%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring occasionally , until beans are wilted and translucent , about 5 minutes
# .:   	99.54%
# (:   	0.16%
# ;:   	0.14%
# ,:   	0.06%
# more:   	0.03%
# --------
#
#
# PROMPT: recipe for chicken and scallops soup | separate garlic cloves , and thyme sprig into pan . heat 3 / 4 cup butter in same wok or wok over high heat . add brown sugar and stir - fry until mixture begins to brown , turning once , about 6 minutes . add tomatoes , onion and garlic ; sauté 1 minute . add pork , remaining 1 / 2 cup reserved juice , 2 tablespoons cilantro , and 2 cups water and cook , stirring occasionally , until beans are wilted and translucent , about 5 minutes .
# add:   	50.77%
# stir:   	9.69%
# remove:   	7.84%
# season:   	6.05%
# discard:   	4.92%
# --------
