# %% [markdown]
# # 🌀 RealNVP

# %% [markdown]
# In this notebook, we'll walk through the steps required to train your own RealNVP network to predict the distribution of a demo dataset

# %% [markdown]
# The code has been adapted from the excellent [RealNVP tutorial](https://keras.io/examples/generative/real_nvp) created by Mandolini Giorgio Maria, Sanna Daniele and Zannini Quirini Giorgio available on the Keras website.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets

import tensorflow as tf
from tensorflow.keras import (
    layers,
    models,
    regularizers,
    metrics,
    optimizers,
    callbacks,
)
import tensorflow_probability as tfp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 0. Parameters <a name="parameters"></a>

# %%
COUPLING_DIM = 256
COUPLING_LAYERS = 2
INPUT_DIM = 2
REGULARIZATION = 0.01
BATCH_SIZE = 256
EPOCHS = 300

# %%
# Load the data
data = datasets.make_moons(30000, noise=0.05)[0].astype("float32")
norm = layers.Normalization()
norm.adapt(data)
normalized_data = norm(data)
plt.scatter(
    normalized_data.numpy()[:, 0], normalized_data.numpy()[:, 1], c="green"
)
plt.show()

# %% [markdown]
# ## 2. Build the RealNVP network <a name="build"></a>

# %%
def Coupling(input_dim, coupling_dim, reg):
    input_layer = layers.Input(shape=(input_dim,))

    s_layer_1 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(input_layer)
    s_layer_2 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_1)
    s_layer_3 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_2)
    s_layer_4 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_3)
    s_layer_5 = layers.Dense(
        input_dim, activation="tanh", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_4)

    t_layer_1 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(input_layer)
    t_layer_2 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_1)
    t_layer_3 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_2)
    t_layer_4 = layers.Dense(
        coupling_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_3)
    t_layer_5 = layers.Dense(
        input_dim, activation="linear", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_4)

    return models.Model(inputs=input_layer, outputs=[s_layer_5, t_layer_5])

# %%
class RealNVP(models.Model):
    def __init__(
        self, input_dim, coupling_layers, coupling_dim, regularization
    ):
        super(RealNVP, self).__init__()
        self.coupling_layers = coupling_layers
        self.distribution = tfp.distributions.MultivariateNormalDiag(
            loc=[0.0, 0.0], scale_diag=[1.0, 1.0]
        )
        self.masks = np.array(
            [[0, 1], [1, 0]] * (coupling_layers // 2), dtype="float32"
        )
        self.loss_tracker = metrics.Mean(name="loss")
        self.layers_list = [
            Coupling(input_dim, coupling_dim, regularization)
            for i in range(coupling_layers)
        ]

    @property
    def metrics(self):
        return [self.loss_tracker]

    def call(self, x, training=True):
        log_det_inv = 0
        direction = 1
        if training:
            direction = -1
        for i in range(self.coupling_layers)[::direction]:
            x_masked = x * self.masks[i]
            reversed_mask = 1 - self.masks[i]
            s, t = self.layers_list[i](x_masked)
            s *= reversed_mask
            t *= reversed_mask
            gate = (direction - 1) / 2
            x = (
                reversed_mask
                * (x * tf.exp(direction * s) + direction * t * tf.exp(gate * s))
                + x_masked
            )
            log_det_inv += gate * tf.reduce_sum(s, axis=1)
        return x, log_det_inv

    def log_loss(self, x):
        y, logdet = self(x)
        log_likelihood = self.distribution.log_prob(y) + logdet
        return -tf.reduce_mean(log_likelihood)

    def train_step(self, data):
        with tf.GradientTape() as tape:
            loss = self.log_loss(data)
        g = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(g, self.trainable_variables))
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

    def test_step(self, data):
        loss = self.log_loss(data)
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}


model = RealNVP(
    input_dim=INPUT_DIM,
    coupling_layers=COUPLING_LAYERS,
    coupling_dim=COUPLING_DIM,
    regularization=REGULARIZATION,
)

# %% [markdown]
# ## 3. Train the RealNVP network <a name="train"></a>

# %%
# Compile and train the model
model.compile(optimizer=optimizers.Adam(learning_rate=0.0001))

# %%
tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")


class ImageGenerator(callbacks.Callback):
    def __init__(self, num_samples):
        self.num_samples = num_samples

    def generate(self):
        # From data to latent space.
        z, _ = model(normalized_data)

        # From latent space to data.
        samples = model.distribution.sample(self.num_samples)
        x, _ = model.predict(samples, verbose=0)

        return x, z, samples

    def display(self, x, z, samples, save_to=None):
        f, axes = plt.subplots(2, 2)
        f.set_size_inches(8, 5)

        axes[0, 0].scatter(
            normalized_data[:, 0], normalized_data[:, 1], color="r", s=1
        )
        axes[0, 0].set(title="Data space X", xlabel="x_1", ylabel="x_2")
        axes[0, 0].set_xlim([-2, 2])
        axes[0, 0].set_ylim([-2, 2])
        axes[0, 1].scatter(z[:, 0], z[:, 1], color="r", s=1)
        axes[0, 1].set(title="f(X)", xlabel="z_1", ylabel="z_2")
        axes[0, 1].set_xlim([-2, 2])
        axes[0, 1].set_ylim([-2, 2])
        axes[1, 0].scatter(samples[:, 0], samples[:, 1], color="g", s=1)
        axes[1, 0].set(title="Latent space Z", xlabel="z_1", ylabel="z_2")
        axes[1, 0].set_xlim([-2, 2])
        axes[1, 0].set_ylim([-2, 2])
        axes[1, 1].scatter(x[:, 0], x[:, 1], color="g", s=1)
        axes[1, 1].set(title="g(Z)", xlabel="x_1", ylabel="x_2")
        axes[1, 1].set_xlim([-2, 2])
        axes[1, 1].set_ylim([-2, 2])

        plt.subplots_adjust(wspace=0.3, hspace=0.6)
        if save_to:
            plt.savefig(save_to)
            print(f"\nSaved to {save_to}")

        plt.show()

    def on_epoch_end(self, epoch, logs=None):
        if epoch % 10 == 0:
            x, z, samples = self.generate()
            self.display(
                x,
                z,
                samples,
                save_to="./output/generated_img_%03d.png" % (epoch),
            )


img_generator_callback = ImageGenerator(num_samples=3000)

# %%
EPOCHS = 600  # Update epochs

# Train the model
history = model.fit(normalized_data, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=1)

# Plot the loss curve
plt.plot(history.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss Curve for RealNVP")
plt.show()
# Out:
# Epoch 1/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 2.6677
# Epoch 2/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3671
# Epoch 3/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2038
# Epoch 4/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 2.0949
# Epoch 5/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.0525
# Epoch 6/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0011
# Epoch 7/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9796
# Epoch 8/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.8376
# Epoch 9/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.7886
# Epoch 10/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7581
# Epoch 11/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7567
# Epoch 12/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7441
# Epoch 13/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7512
# Epoch 14/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7397
# Epoch 15/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7471
# Epoch 16/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7341
# Epoch 17/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7377
# Epoch 18/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7414
# Epoch 19/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7215
# Epoch 20/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7233
# Epoch 21/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7287
# Epoch 22/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7173
# Epoch 23/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7182
# Epoch 24/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7289
# Epoch 25/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7205
# Epoch 26/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7228
# Epoch 27/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7184
# Epoch 28/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7166
# Epoch 29/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7246
# Epoch 30/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7231
# Epoch 31/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7172
# Epoch 32/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7201
# Epoch 33/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7130
# Epoch 34/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7156
# Epoch 35/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7054
# Epoch 36/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.7157
# Epoch 37/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7115
# Epoch 38/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7260
# Epoch 39/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7168
# Epoch 40/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7007
# Epoch 41/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7140
# Epoch 42/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7132
# Epoch 43/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7048
# Epoch 44/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.7082
# Epoch 45/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7182
# Epoch 46/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7098
# Epoch 47/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7145
# Epoch 48/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7076
# Epoch 49/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7220
# Epoch 50/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7076
# Epoch 51/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7177
# Epoch 52/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7221
# Epoch 53/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7186
# Epoch 54/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7120
# Epoch 55/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7084
# Epoch 56/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7094
# Epoch 57/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7080
# Epoch 58/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7198
# Epoch 59/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7122
# Epoch 60/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7024
# Epoch 61/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7104
# Epoch 62/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7287
# Epoch 63/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7019
# Epoch 64/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7150
# Epoch 65/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7133
# Epoch 66/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7150
# Epoch 67/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7216
# Epoch 68/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7125
# Epoch 69/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7057
# Epoch 70/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7137
# Epoch 71/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7158
# Epoch 72/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7082
# Epoch 73/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7064
# Epoch 74/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7117
# Epoch 75/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7051
# Epoch 76/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7161
# Epoch 77/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7114
# Epoch 78/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7085
# Epoch 79/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7133
# Epoch 80/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7098
# Epoch 81/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7015
# Epoch 82/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7146
# Epoch 83/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.7054
# Epoch 84/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.7136
# Epoch 85/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7079
# Epoch 86/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.7178
# Epoch 87/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.7156
# Epoch 88/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.7117
# Epoch 89/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7158
# Epoch 90/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7063
# Epoch 91/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7110
# Epoch 92/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7163
# Epoch 93/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7023
# Epoch 94/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7145
# Epoch 95/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7153
# Epoch 96/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7094
# Epoch 97/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6990
# Epoch 98/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7152
# Epoch 99/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7015
# Epoch 100/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7160
# Epoch 101/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7119
# Epoch 102/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7090
# Epoch 103/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7214
# Epoch 104/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7060
# Epoch 105/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7060
# Epoch 106/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.7040
# Epoch 107/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.7112
# Epoch 108/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7065
# Epoch 109/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.7094
# Epoch 110/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6974
# Epoch 111/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.7069
# Epoch 112/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7135
# Epoch 113/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7121
# Epoch 114/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7064
# Epoch 115/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6993
# Epoch 116/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7118
# Epoch 117/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7056
# Epoch 118/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7108
# Epoch 119/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7075
# Epoch 120/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.7063
# Epoch 121/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.6999
# Epoch 122/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6963
# Epoch 123/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7087
# Epoch 124/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.7063
# Epoch 125/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7097
# Epoch 126/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7115
# Epoch 127/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7012
# Epoch 128/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7037
# Epoch 129/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.7100
# Epoch 130/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.7133
# Epoch 131/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7111
# Epoch 132/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7032
# Epoch 133/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.7084
# Epoch 134/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7043
# Epoch 135/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7074
# Epoch 136/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7089
# Epoch 137/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7056
# Epoch 138/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7075
# Epoch 139/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6956
# Epoch 140/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6992
# Epoch 141/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7140
# Epoch 142/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7069
# Epoch 143/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7031
# Epoch 144/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7001
# Epoch 145/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7122
# Epoch 146/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7006
# Epoch 147/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7086
# Epoch 148/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7123
# Epoch 149/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7058
# Epoch 150/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7118
# Epoch 151/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7185
# Epoch 152/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7155
# Epoch 153/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7134
# Epoch 154/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6987
# Epoch 155/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7052
# Epoch 156/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6953
# Epoch 157/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7108
# Epoch 158/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7075
# Epoch 159/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7164
# Epoch 160/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6975
# Epoch 161/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6966
# Epoch 162/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7087
# Epoch 163/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7109
# Epoch 164/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7011
# Epoch 165/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7058
# Epoch 166/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7050
# Epoch 167/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7059
# Epoch 168/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7020
# Epoch 169/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7035
# Epoch 170/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7093
# Epoch 171/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7049
# Epoch 172/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7032
# Epoch 173/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7073
# Epoch 174/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6937
# Epoch 175/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7001
# Epoch 176/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7067
# Epoch 177/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7013
# Epoch 178/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7007
# Epoch 179/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7057
# Epoch 180/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7004
# Epoch 181/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7081
# Epoch 182/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7023
# Epoch 183/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7032
# Epoch 184/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7002
# Epoch 185/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7095
# Epoch 186/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6897
# Epoch 187/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7005
# Epoch 188/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7017
# Epoch 189/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7059
# Epoch 190/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7013
# Epoch 191/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7030
# Epoch 192/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7054
# Epoch 193/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6995
# Epoch 194/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7028
# Epoch 195/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7110
# Epoch 196/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7062
# Epoch 197/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7045
# Epoch 198/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7028
# Epoch 199/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7092
# Epoch 200/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7159
# Epoch 201/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7071
# Epoch 202/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7040
# Epoch 203/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6987
# Epoch 204/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7007
# Epoch 205/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7003
# Epoch 206/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6948
# Epoch 207/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7338
# Epoch 208/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7026
# Epoch 209/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7036
# Epoch 210/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7066
# Epoch 211/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6997
# Epoch 212/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7047
# Epoch 213/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7073
# Epoch 214/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7050
# Epoch 215/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7045
# Epoch 216/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7038
# Epoch 217/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7051
# Epoch 218/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7040
# Epoch 219/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7050
# Epoch 220/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6929
# Epoch 221/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7067
# Epoch 222/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6917
# Epoch 223/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7037
# Epoch 224/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7017
# Epoch 225/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6949
# Epoch 226/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7056
# Epoch 227/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7026
# Epoch 228/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6987
# Epoch 229/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7081
# Epoch 230/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6998
# Epoch 231/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.6983
# Epoch 232/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7097
# Epoch 233/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7030
# Epoch 234/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7073
# Epoch 235/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7137
# Epoch 236/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7140
# Epoch 237/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6962
# Epoch 238/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7003
# Epoch 239/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7004
# Epoch 240/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7069
# Epoch 241/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7082
# Epoch 242/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6969
# Epoch 243/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6984
# Epoch 244/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7102
# Epoch 245/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7014
# Epoch 246/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6998
# Epoch 247/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6983
# Epoch 248/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7064
# Epoch 249/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7045
# Epoch 250/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7013
# Epoch 251/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7028
# Epoch 252/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6954
# Epoch 253/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7000
# Epoch 254/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6995
# Epoch 255/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.7046
# Epoch 256/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.6982
# Epoch 257/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.7084
# Epoch 258/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7047
# Epoch 259/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6923
# Epoch 260/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6968
# Epoch 261/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7031
# Epoch 262/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7043
# Epoch 263/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7014
# Epoch 264/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7104
# Epoch 265/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7019
# Epoch 266/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7048
# Epoch 267/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6950
# Epoch 268/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7049
# Epoch 269/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6961
# Epoch 270/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7094
# Epoch 271/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6963
# Epoch 272/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6927
# Epoch 273/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6990
# Epoch 274/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6945
# Epoch 275/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6970
# Epoch 276/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7051
# Epoch 277/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7042
# Epoch 278/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7010
# Epoch 279/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6982
# Epoch 280/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6959
# Epoch 281/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6907
# Epoch 282/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7069
# Epoch 283/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7008
# Epoch 284/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7009
# Epoch 285/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6959
# Epoch 286/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6996
# Epoch 287/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6965
# Epoch 288/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6989
# Epoch 289/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7010
# Epoch 290/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7028
# Epoch 291/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7084
# Epoch 292/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6906
# Epoch 293/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6955
# Epoch 294/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7038
# Epoch 295/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7006
# Epoch 296/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6967
# Epoch 297/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6970
# Epoch 298/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7242
# Epoch 299/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6969
# Epoch 300/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6984
# Epoch 301/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6954
# Epoch 302/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7024
# Epoch 303/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6969
# Epoch 304/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7009
# Epoch 305/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6982
# Epoch 306/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6997
# Epoch 307/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7050
# Epoch 308/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7003
# Epoch 309/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6961
# Epoch 310/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7132
# Epoch 311/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6988
# Epoch 312/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6958
# Epoch 313/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6989
# Epoch 314/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7018
# Epoch 315/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6994
# Epoch 316/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7018
# Epoch 317/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7023
# Epoch 318/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7023
# Epoch 319/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6981
# Epoch 320/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6951
# Epoch 321/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7019
# Epoch 322/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6949
# Epoch 323/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7055
# Epoch 324/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7030
# Epoch 325/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6940
# Epoch 326/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7000
# Epoch 327/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6933
# Epoch 328/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6944
# Epoch 329/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7021
# Epoch 330/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7016
# Epoch 331/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7072
# Epoch 332/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6937
# Epoch 333/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6975
# Epoch 334/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6967
# Epoch 335/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6953
# Epoch 336/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6984
# Epoch 337/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6984
# Epoch 338/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6877
# Epoch 339/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6911
# Epoch 340/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7115
# Epoch 341/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6938
# Epoch 342/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6994
# Epoch 343/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6989
# Epoch 344/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7061
# Epoch 345/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6970
# Epoch 346/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7111
# Epoch 347/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7048
# Epoch 348/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7075
# Epoch 349/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7024
# Epoch 350/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6966
# Epoch 351/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6872
# Epoch 352/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6932
# Epoch 353/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7010
# Epoch 354/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6832
# Epoch 355/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7006
# Epoch 356/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6970
# Epoch 357/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7005
# Epoch 358/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.6968
# Epoch 359/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.6933
# Epoch 360/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6978
# Epoch 361/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7233
# Epoch 362/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7055
# Epoch 363/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.7026
# Epoch 364/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6894
# Epoch 365/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 1.7013
# Epoch 366/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6997
# Epoch 367/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7168
# Epoch 368/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7034
# Epoch 369/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7045
# Epoch 370/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7070
# Epoch 371/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7077
# Epoch 372/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6960
# Epoch 373/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7047
# Epoch 374/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6927
# Epoch 375/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7023
# Epoch 376/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6995
# Epoch 377/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6978
# Epoch 378/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6934
# Epoch 379/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.7035
# Epoch 380/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.7090
# Epoch 381/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6858
# Epoch 382/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6896
# Epoch 383/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6932
# Epoch 384/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6938
# Epoch 385/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6867
# Epoch 386/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.7057
# Epoch 387/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6965
# Epoch 388/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.7028
# Epoch 389/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.7006
# Epoch 390/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.7046
# Epoch 391/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.7058
# Epoch 392/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6892
# Epoch 393/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7001
# Epoch 394/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6927
# Epoch 395/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6875
# Epoch 396/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6989
# Epoch 397/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7006
# Epoch 398/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6993
# Epoch 399/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6948
# Epoch 400/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.6991
# Epoch 401/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7070
# Epoch 402/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6994
# Epoch 403/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6952
# Epoch 404/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7091
# Epoch 405/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6980
# Epoch 406/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6965
# Epoch 407/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6975
# Epoch 408/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.6957
# Epoch 409/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.6954
# Epoch 410/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7037
# Epoch 411/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6994
# Epoch 412/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6916
# Epoch 413/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6936
# Epoch 414/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7025
# Epoch 415/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7053
# Epoch 416/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6940
# Epoch 417/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6978
# Epoch 418/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6963
# Epoch 419/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6908
# Epoch 420/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6857
# Epoch 421/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7021
# Epoch 422/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6927
# Epoch 423/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6964
# Epoch 424/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6939
# Epoch 425/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6977
# Epoch 426/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7002
# Epoch 427/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7066
# Epoch 428/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6947
# Epoch 429/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6925
# Epoch 430/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6859
# Epoch 431/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7039
# Epoch 432/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6960
# Epoch 433/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7007
# Epoch 434/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6964
# Epoch 435/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6919
# Epoch 436/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7006
# Epoch 437/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7020
# Epoch 438/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6992
# Epoch 439/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6992
# Epoch 440/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7013
# Epoch 441/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6940
# Epoch 442/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7062
# Epoch 443/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6992
# Epoch 444/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6965
# Epoch 445/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6954
# Epoch 446/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.7002
# Epoch 447/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6960
# Epoch 448/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6976
# Epoch 449/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6950
# Epoch 450/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6998
# Epoch 451/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6985
# Epoch 452/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6983
# Epoch 453/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6896
# Epoch 454/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6975
# Epoch 455/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6991
# Epoch 456/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6924
# Epoch 457/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6971
# Epoch 458/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7024
# Epoch 459/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6982
# Epoch 460/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.7017
# Epoch 461/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6993
# Epoch 462/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6962
# Epoch 463/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7057
# Epoch 464/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7030
# Epoch 465/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7008
# Epoch 466/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6934
# Epoch 467/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6941
# Epoch 468/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6971
# Epoch 469/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6941
# Epoch 470/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6875
# Epoch 471/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7014
# Epoch 472/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6989
# Epoch 473/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6887
# Epoch 474/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6912
# Epoch 475/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6987
# Epoch 476/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6926
# Epoch 477/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7047
# Epoch 478/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7039
# Epoch 479/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6884
# Epoch 480/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6923
# Epoch 481/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6891
# Epoch 482/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6978
# Epoch 483/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6939
# Epoch 484/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6993
# Epoch 485/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7164
# Epoch 486/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7028
# Epoch 487/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6951
# Epoch 488/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6897
# Epoch 489/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6920
# Epoch 490/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6978
# Epoch 491/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6966
# Epoch 492/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6989
# Epoch 493/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.6946
# Epoch 494/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6988
# Epoch 495/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7003
# Epoch 496/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.6869
# Epoch 497/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.7038
# Epoch 498/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6920
# Epoch 499/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6919
# Epoch 500/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6871
# Epoch 501/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7065
# Epoch 502/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6975
# Epoch 503/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6969
# Epoch 504/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6957
# Epoch 505/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6895
# Epoch 506/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6931
# Epoch 507/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.7155
# Epoch 508/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6996
# Epoch 509/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6951
# Epoch 510/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6929
# Epoch 511/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6967
# Epoch 512/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6908
# Epoch 513/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7078
# Epoch 514/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6867
# Epoch 515/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6986
# Epoch 516/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6955
# Epoch 517/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.6953
# Epoch 518/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.6935
# Epoch 519/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6965
# Epoch 520/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6933
# Epoch 521/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6867
# Epoch 522/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7011
# Epoch 523/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6958
# Epoch 524/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7005
# Epoch 525/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6912
# Epoch 526/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.6927
# Epoch 527/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7085
# Epoch 528/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6969
# Epoch 529/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7054
# Epoch 530/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6937
# Epoch 531/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6899
# Epoch 532/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 1.6903
# Epoch 533/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6998
# Epoch 534/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6927
# Epoch 535/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7031
# Epoch 536/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6929
# Epoch 537/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.6895
# Epoch 538/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.6874
# Epoch 539/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6962
# Epoch 540/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6989
# Epoch 541/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6928
# Epoch 542/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7092
# Epoch 543/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7037
# Epoch 544/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6940
# Epoch 545/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7012
# Epoch 546/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6996
# Epoch 547/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6915
# Epoch 548/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6901
# Epoch 549/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6893
# Epoch 550/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6930
# Epoch 551/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6918
# Epoch 552/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6932
# Epoch 553/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6956
# Epoch 554/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6850
# Epoch 555/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6987
# Epoch 556/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6983
# Epoch 557/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6923
# Epoch 558/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6893
# Epoch 559/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6944
# Epoch 560/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6920
# Epoch 561/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.7072
# Epoch 562/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7006
# Epoch 563/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6839
# Epoch 564/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6943
# Epoch 565/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.7051
# Epoch 566/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6900
# Epoch 567/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6835
# Epoch 568/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7016
# Epoch 569/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6992
# Epoch 570/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6935
# Epoch 571/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6975
# Epoch 572/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6920
# Epoch 573/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6923
# Epoch 574/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.6891
# Epoch 575/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1.6974
# Epoch 576/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.6985
# Epoch 577/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6907
# Epoch 578/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6908
# Epoch 579/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6955
# Epoch 580/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7009
# Epoch 581/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6905
# Epoch 582/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.6957
# Epoch 583/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6938
# Epoch 584/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7078
# Epoch 585/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.6989
# Epoch 586/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6872
# Epoch 587/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6959
# Epoch 588/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6929
# Epoch 589/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7060
# Epoch 590/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.7016
# Epoch 591/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6900
# Epoch 592/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.6975
# Epoch 593/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.6950
# Epoch 594/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7040
# Epoch 595/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1.6907
# Epoch 596/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.6939
# Epoch 597/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6952
# Epoch 598/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6956
# Epoch 599/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7078
# Epoch 600/600
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6982

# %% [markdown]
# ## 4. Generate images <a name="generate"></a>

# %%
x, z, samples = img_generator_callback.generate()

# %%
img_generator_callback.display(x, z, samples)
